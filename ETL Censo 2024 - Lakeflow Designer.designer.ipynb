# %%
"""
id: source_0
template: source
name: hogares_censo2024
position:
  x: 0
  y: 232.5
description:
  text: Load data from a parquet file.
  hash: b9853e07
previewCodeHash: 2d3f7235a9c7d401
previewMode: "1000"
config:
  file_source:
    path: /Volumes/workspace/tbl_censo/censo_volume/original/hogares_censo2024.parquet
    format: '"parquet"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/workspace/tbl_censo/censo_volume/original/hogares_censo2024.parquet",
        "format": "\"parquet\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_0.data"] = out["data"]

# %%
"""
id: source_0_copy
template: source
name: personas_censo2024
position:
  x: 300
  y: 0
description:
  text: Read all data from a parquet file.
  hash: 6d34588b
previewCodeHash: b7a61b58e3435651
previewMode: "1000"
config:
  file_source:
    path: /Volumes/workspace/tbl_censo/censo_volume/original/personas_censo2024.parquet
    format: '"parquet"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/workspace/tbl_censo/censo_volume/original/personas_censo2024.parquet",
        "format": "\"parquet\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_0_copy.data"] = out["data"]

# %%
"""
id: source_0_copy_1
template: source
name: viviendas_censo2024
position:
  x: 0
  y: 77.5
description:
  text: Load data from a parquet file.
  hash: 7b3c426b
previewCodeHash: 0ecf904ca227b468
previewMode: "1000"
config:
  file_source:
    path: /Volumes/workspace/tbl_censo/censo_volume/original/viviendas_censo2024.parquet
    format: '"parquet"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/workspace/tbl_censo/censo_volume/original/viviendas_censo2024.parquet",
        "format": "\"parquet\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_0_copy_1.data"] = out["data"]

# %%
"""
id: source_5
template: source
name: codigos_otros_v2
position:
  x: 600
  y: 232.5
description:
  text: Read a CSV file with semicolon delimiter from specified path.
  hash: d32ea4de
previewCodeHash: d6a0668c43b7d632
previewMode: "1000"
config:
  file_source:
    path: /Volumes/workspace/tbl_censo/censo_volume/original/codigos_otros_v2.csv
    format: '"csv"'
    delimiter: '";"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/workspace/tbl_censo/censo_volume/original/codigos_otros_v2.csv",
        "format": "\"csv\"",
        "delimiter": "\";\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_5.data"] = out["data"]

# %%
"""
id: source_7
template: source
name: codigos_territoriales
position:
  x: 900
  y: 310
description:
  text: Load all data from a CSV file at the specified path.
  hash: 9f7de526
previewCodeHash: 05128e4e8c10b2a9
previewMode: "1000"
config:
  file_source:
    path: /Volumes/workspace/tbl_censo/censo_volume/original/codigos_territoriales.csv
    format: '"csv"'
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "file_source": {
        "path": "/Volumes/workspace/tbl_censo/censo_volume/original/codigos_territoriales.csv",
        "format": "\"csv\""
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_7.data"] = out["data"]

# %%
"""
id: join_3
template: join
name: join_vivienda_hogar
position:
  x: 300
  y: 155
description:
  text: Combine records from two data sets based on matching house IDs, keeping all from the left and selected columns from both.
  hash: 211fc99b
previewCodeHash: 6a17290657705cd9
previewMode: "1000"
config:
  join_type: left
  join_conditions: left.id_vivienda = right.id_vivienda
  expressions:
    - "`right`.id_vivienda `hogar_id_vivienda`"
    - "`right`.id_hogar `hogar_id_hogar`"
    - "`right`.region `hogar_region`"
    - "`right`.provincia `hogar_provincia`"
    - "`right`.comuna `hogar_comuna`"
    - "`right`.comuna_bajo_umbral `hogar_comuna_bajo_umbral`"
    - "`right`.area `hogar_area`"
    - "`right`.tipo_operativo `hogar_tipo_operativo`"
    - "`right`.p12_tenencia_viv"
    - "`right`.p13_comb_cocina"
    - "`right`.p14_comb_calefaccion"
    - "`right`.p15a_serv_tel_movil"
    - "`right`.p15b_serv_compu"
    - "`right`.p15c_serv_tablet"
    - "`right`.p15d_serv_internet_fija"
    - "`right`.p15e_serv_internet_movil"
    - "`right`.p15f_serv_internet_satelital"
    - "`right`.tipologia_hogar"
    - "`right`._rescued_data `hogar_rescued_data`"
    - "`left`.provincia `vivienda_provincia`"
    - "`left`.comuna `vivienda_comuna`"
    - "`left`.comuna_bajo_umbral `vivienda_comuna_bajo_umbral`"
    - "`left`.area `vivienda_area`"
    - "`left`.tipo_operativo `tipo_operativo`"
    - "`left`.cant_hog"
    - "`left`.cant_per"
    - "`left`.p2_tipo_vivienda"
    - "`left`.p3a_estado_ocupacion"
    - "`left`.p3b_estado_ocupacion"
    - "`left`.p4a_mat_paredes"
    - "`left`.p4b_mat_techo"
    - "`left`.p4c_mat_piso"
    - "`left`.p5_num_dormitorios"
    - "`left`.p6_fuente_agua"
    - "`left`.p7_distrib_agua"
    - "`left`.p8_serv_hig"
    - "`left`.p9_fuente_elect"
    - "`left`.p10_basura"
    - "`left`.p11a_num_personas"
    - "`left`.p11b_comparte_gasto"
    - "`left`.p11c_num_hogar"
    - "`left`.indice_hacinamiento"
    - "`left`.region `vivienda_region`"
input:
  - node: source_0_copy_1
    input_port: left
    output_port: data
  - node: source_0
    input_port: right
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "left.id_vivienda = right.id_vivienda",
    "expressions": [
        "`right`.id_vivienda `hogar_id_vivienda`",
        "`right`.id_hogar `hogar_id_hogar`",
        "`right`.region `hogar_region`",
        "`right`.provincia `hogar_provincia`",
        "`right`.comuna `hogar_comuna`",
        "`right`.comuna_bajo_umbral `hogar_comuna_bajo_umbral`",
        "`right`.area `hogar_area`",
        "`right`.tipo_operativo `hogar_tipo_operativo`",
        "`right`.p12_tenencia_viv",
        "`right`.p13_comb_cocina",
        "`right`.p14_comb_calefaccion",
        "`right`.p15a_serv_tel_movil",
        "`right`.p15b_serv_compu",
        "`right`.p15c_serv_tablet",
        "`right`.p15d_serv_internet_fija",
        "`right`.p15e_serv_internet_movil",
        "`right`.p15f_serv_internet_satelital",
        "`right`.tipologia_hogar",
        "`right`._rescued_data `hogar_rescued_data`",
        "`left`.provincia `vivienda_provincia`",
        "`left`.comuna `vivienda_comuna`",
        "`left`.comuna_bajo_umbral `vivienda_comuna_bajo_umbral`",
        "`left`.area `vivienda_area`",
        "`left`.tipo_operativo `tipo_operativo`",
        "`left`.cant_hog",
        "`left`.cant_per",
        "`left`.p2_tipo_vivienda",
        "`left`.p3a_estado_ocupacion",
        "`left`.p3b_estado_ocupacion",
        "`left`.p4a_mat_paredes",
        "`left`.p4b_mat_techo",
        "`left`.p4c_mat_piso",
        "`left`.p5_num_dormitorios",
        "`left`.p6_fuente_agua",
        "`left`.p7_distrib_agua",
        "`left`.p8_serv_hig",
        "`left`.p9_fuente_elect",
        "`left`.p10_basura",
        "`left`.p11a_num_personas",
        "`left`.p11b_comparte_gasto",
        "`left`.p11c_num_hogar",
        "`left`.indice_hacinamiento",
        "`left`.region `vivienda_region`"
    ]
}
inputs = {
    "left": ctx["source_0_copy_1.data"],
    "right": ctx["source_0.data"]
}
out = run(config, inputs, spark)
ctx["join_3.joined_data"] = out["joined_data"]

# %%
"""
id: join_4
template: join
name: join_personas_hogar_vivienda
position:
  x: 600
  y: 77.5
description:
  text: Perform a left join on the two datasets using matching housing and household IDs, keeping selected columns from both sides.
  hash: 9bd80cab
previewCodeHash: 86b61361d8c870bc
previewMode: "1000"
config:
  join_type: left
  join_conditions: (left.id_vivienda = right.hogar_id_vivienda) AND (left.id_hogar = right.hogar_id_hogar)
  expressions:
    - "`left`.id_vivienda `id_vivienda`"
    - "`left`.id_hogar `id_hogar`"
    - "`left`.id_persona"
    - "`left`.region"
    - "`left`.provincia `provincia`"
    - "`left`.comuna `comuna`"
    - "`left`.comuna_bajo_umbral `comuna_bajo_umbral`"
    - "`left`.area `area`"
    - "`left`.tipo_operativo `tipo_operativo`"
    - "`left`.sexo"
    - "`left`.edad"
    - "`left`.edad_quinquenal"
    - "`left`.parentesco"
    - "`left`.p23_est_civil"
    - "`left`.p24_lug_resid5"
    - "`left`.p24_lug_resid5_esp"
    - "`left`.p25_lug_nacimiento"
    - "`left`.p25_lug_nacimiento_rec"
    - "`left`.p25_lug_nacimiento_esp"
    - "`left`.p26_llegada_periodo"
    - "`left`.p27_nacionalidad"
    - "`left`.p27_nacionalidad_esp"
    - "`left`.p27_nacionalidad_rec"
    - "`left`.p28_autoid_pueblo"
    - "`left`.p28_pueblo_pert"
    - "`left`.p29_afrodescendencia_rec"
    - "`left`.p29_afrodescendencia"
    - "`left`.p30_lengua_indigena"
    - "`left`.p30_lengua_indigena_rec"
    - "`left`.p31_religion"
    - "`left`.p31_religion_rec"
    - "`left`.p32a_dificultad_ver"
    - "`left`.p32b_dificultad_oir"
    - "`left`.p32c_dificultad_mover"
    - "`left`.p32d_dificultad_cogni"
    - "`left`.p32e_dificultad_cuidado"
    - "`left`.p32f_dificultad_comunic"
    - "`left`.discapacidad"
    - "`left`.p33_edu_asiste"
    - "`left`.asistencia_parv"
    - "`left`.asistencia_basica"
    - "`left`.asistencia_media"
    - "`left`.asistencia_superior"
    - "`left`.p37_alfabet"
    - "`left`.escolaridad"
    - "`left`.cine11"
    - "`left`.sit_fuerza_trabajo"
    - "`left`.p40_cise_rec"
    - "`left`.depend_econ_deficit_hab"
    - "`left`.cod_ciuo"
    - "`left`.cod_caenes"
    - "`left`.p44_lug_trab"
    - "`left`.p44_lug_trab_esp"
    - "`left`.p45_medio_transporte"
    - "`left`.p46a_tot_hijs_nac"
    - "`left`.p46b_hijas_nac"
    - "`left`.p46c_hijos_nac"
    - "`left`.p47a_tot_hijs_sobrev"
    - "`left`.p47b_hijas_sobrev"
    - "`left`.p47c_hijos_sobrev"
    - "`left`.p48_anio_nac_uh"
    - "`left`.p48_mes_nac_uh"
    - "`left`.div_genero"
    - "`right`.hogar_region"
    - "`right`.hogar_provincia"
    - "`right`.hogar_comuna"
    - "`right`.hogar_comuna_bajo_umbral"
    - "`right`.hogar_area"
    - "`right`.hogar_tipo_operativo"
    - "`right`.p12_tenencia_viv"
    - "`right`.p13_comb_cocina"
    - "`right`.p14_comb_calefaccion"
    - "`right`.p15a_serv_tel_movil"
    - "`right`.p15b_serv_compu"
    - "`right`.p15c_serv_tablet"
    - "`right`.p15d_serv_internet_fija"
    - "`right`.p15e_serv_internet_movil"
    - "`right`.p15f_serv_internet_satelital"
    - "`right`.tipologia_hogar"
    - "`right`.tipo_operativo `right_tipo_operativo`"
    - "`right`.cant_hog"
    - "`right`.cant_per"
    - "`right`.p2_tipo_vivienda"
    - "`right`.p3a_estado_ocupacion"
    - "`right`.p3b_estado_ocupacion"
    - "`right`.p4a_mat_paredes"
    - "`right`.p4b_mat_techo"
    - "`right`.p4c_mat_piso"
    - "`right`.p5_num_dormitorios"
    - "`right`.p6_fuente_agua"
    - "`right`.p7_distrib_agua"
    - "`right`.p8_serv_hig"
    - "`right`.p9_fuente_elect"
    - "`right`.p10_basura"
    - "`right`.p11a_num_personas"
    - "`right`.p11b_comparte_gasto"
    - "`right`.p11c_num_hogar"
    - "`right`.indice_hacinamiento"
    - "`right`.vivienda_provincia"
    - "`right`.vivienda_comuna"
    - "`right`.vivienda_comuna_bajo_umbral"
    - "`right`.vivienda_area"
    - "`right`.vivienda_region"
input:
  - node: source_0_copy
    input_port: left
    output_port: data
  - node: join_3
    input_port: right
    output_port: joined_data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "left",
    "join_conditions": "(left.id_vivienda = right.hogar_id_vivienda) AND (left.id_hogar = right.hogar_id_hogar)",
    "expressions": [
        "`left`.id_vivienda `id_vivienda`",
        "`left`.id_hogar `id_hogar`",
        "`left`.id_persona",
        "`left`.region",
        "`left`.provincia `provincia`",
        "`left`.comuna `comuna`",
        "`left`.comuna_bajo_umbral `comuna_bajo_umbral`",
        "`left`.area `area`",
        "`left`.tipo_operativo `tipo_operativo`",
        "`left`.sexo",
        "`left`.edad",
        "`left`.edad_quinquenal",
        "`left`.parentesco",
        "`left`.p23_est_civil",
        "`left`.p24_lug_resid5",
        "`left`.p24_lug_resid5_esp",
        "`left`.p25_lug_nacimiento",
        "`left`.p25_lug_nacimiento_rec",
        "`left`.p25_lug_nacimiento_esp",
        "`left`.p26_llegada_periodo",
        "`left`.p27_nacionalidad",
        "`left`.p27_nacionalidad_esp",
        "`left`.p27_nacionalidad_rec",
        "`left`.p28_autoid_pueblo",
        "`left`.p28_pueblo_pert",
        "`left`.p29_afrodescendencia_rec",
        "`left`.p29_afrodescendencia",
        "`left`.p30_lengua_indigena",
        "`left`.p30_lengua_indigena_rec",
        "`left`.p31_religion",
        "`left`.p31_religion_rec",
        "`left`.p32a_dificultad_ver",
        "`left`.p32b_dificultad_oir",
        "`left`.p32c_dificultad_mover",
        "`left`.p32d_dificultad_cogni",
        "`left`.p32e_dificultad_cuidado",
        "`left`.p32f_dificultad_comunic",
        "`left`.discapacidad",
        "`left`.p33_edu_asiste",
        "`left`.asistencia_parv",
        "`left`.asistencia_basica",
        "`left`.asistencia_media",
        "`left`.asistencia_superior",
        "`left`.p37_alfabet",
        "`left`.escolaridad",
        "`left`.cine11",
        "`left`.sit_fuerza_trabajo",
        "`left`.p40_cise_rec",
        "`left`.depend_econ_deficit_hab",
        "`left`.cod_ciuo",
        "`left`.cod_caenes",
        "`left`.p44_lug_trab",
        "`left`.p44_lug_trab_esp",
        "`left`.p45_medio_transporte",
        "`left`.p46a_tot_hijs_nac",
        "`left`.p46b_hijas_nac",
        "`left`.p46c_hijos_nac",
        "`left`.p47a_tot_hijs_sobrev",
        "`left`.p47b_hijas_sobrev",
        "`left`.p47c_hijos_sobrev",
        "`left`.p48_anio_nac_uh",
        "`left`.p48_mes_nac_uh",
        "`left`.div_genero",
        "`right`.hogar_region",
        "`right`.hogar_provincia",
        "`right`.hogar_comuna",
        "`right`.hogar_comuna_bajo_umbral",
        "`right`.hogar_area",
        "`right`.hogar_tipo_operativo",
        "`right`.p12_tenencia_viv",
        "`right`.p13_comb_cocina",
        "`right`.p14_comb_calefaccion",
        "`right`.p15a_serv_tel_movil",
        "`right`.p15b_serv_compu",
        "`right`.p15c_serv_tablet",
        "`right`.p15d_serv_internet_fija",
        "`right`.p15e_serv_internet_movil",
        "`right`.p15f_serv_internet_satelital",
        "`right`.tipologia_hogar",
        "`right`.tipo_operativo `right_tipo_operativo`",
        "`right`.cant_hog",
        "`right`.cant_per",
        "`right`.p2_tipo_vivienda",
        "`right`.p3a_estado_ocupacion",
        "`right`.p3b_estado_ocupacion",
        "`right`.p4a_mat_paredes",
        "`right`.p4b_mat_techo",
        "`right`.p4c_mat_piso",
        "`right`.p5_num_dormitorios",
        "`right`.p6_fuente_agua",
        "`right`.p7_distrib_agua",
        "`right`.p8_serv_hig",
        "`right`.p9_fuente_elect",
        "`right`.p10_basura",
        "`right`.p11a_num_personas",
        "`right`.p11b_comparte_gasto",
        "`right`.p11c_num_hogar",
        "`right`.indice_hacinamiento",
        "`right`.vivienda_provincia",
        "`right`.vivienda_comuna",
        "`right`.vivienda_comuna_bajo_umbral",
        "`right`.vivienda_area",
        "`right`.vivienda_region"
    ]
}
inputs = {
    "left": ctx["source_0_copy.data"],
    "right": ctx["join_3.joined_data"]
}
out = run(config, inputs, spark)
ctx["join_4.joined_data"] = out["joined_data"]

# %%
"""
id: python_6
template: python
name: convert_codigos_otros
position:
  x: 900
  y: 155
description:
  text: Replace codes in columns based on descriptions from a reference table.
  hash: 5f81b4df
previewMode: "1000"
config:
  code: |-
    # inputs["data"] is a list of input DataFrames.
    # Assign your result to the variable "result".

    if inputs["data"]:
        result = inputs["data"][0]
    else:
        result = spark.createDataFrame([], "col: string")

    df_personas = inputs["data"][0]
    df_codigos = inputs["data"][1]

    def build_codigos_expr(df_codigos, column):
        df_codigos_col = df_codigos.filter(df_codigos.Campo == column)
        # Como hacer con los campos "hogar_area", "vivienda_area", etc?
        # Ya que el nombre fue para arrastrar el campo, pero en la tabla "codigos" se llaman "area", sin el prefijo
        exprs = []
        for row in df_codigos_col.collect():
            codigo = row['Codigo']
            descripcion = row['Descripcion']
            if codigo == 'NA':
                exprs.append(f"WHEN CAST({column} AS STRING) IS NULL THEN '{descripcion}'")
                exprs.append(f"WHEN CAST({column} AS STRING) = 'NA' THEN '{descripcion}'")
            elif ':' in codigo:
                start, end = codigo.split(':')
                exprs.append(f"WHEN CAST({column} AS STRING) BETWEEN '{start}' AND '{end}' THEN CAST({column} AS STRING)")
            else:
                exprs.append(f"WHEN CAST({column} AS STRING) = '{codigo}' THEN '{descripcion}'")

        if exprs:
            case_expr =  f"CASE {' '.join(exprs)} ELSE CAST({column} AS STRING) END"
        else:
            case_expr = column
        return F.expr(case_expr).alias(column)

    df_result = df_personas
    for column in df_personas.columns:
        df_result = df_result.withColumn(f"{column}_new", build_codigos_expr(df_codigos, column))
        df_result = df_result.drop(column)
        df_result = df_result.withColumnRenamed(f"{column}_new", column)

    result = df_result
input:
  - node: join_4
    input_port: data
    output_port: joined_data
  - node: source_5
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # inputs["data"] is a list of input DataFrames.
    # Assign your result to the variable "result".

    if inputs["data"]:
        result = inputs["data"][0]
    else:
        result = spark.createDataFrame([], "col: string")

    df_personas = inputs["data"][0]
    df_codigos = inputs["data"][1]

    def build_codigos_expr(df_codigos, column):
        df_codigos_col = df_codigos.filter(df_codigos.Campo == column)
        # Como hacer con los campos "hogar_area", "vivienda_area", etc?
        # Ya que el nombre fue para arrastrar el campo, pero en la tabla "codigos" se llaman "area", sin el prefijo
        exprs = []
        for row in df_codigos_col.collect():
            codigo = row['Codigo']
            descripcion = row['Descripcion']
            if codigo == 'NA':
                exprs.append(f"WHEN CAST({column} AS STRING) IS NULL THEN '{descripcion}'")
                exprs.append(f"WHEN CAST({column} AS STRING) = 'NA' THEN '{descripcion}'")
            elif ':' in codigo:
                start, end = codigo.split(':')
                exprs.append(f"WHEN CAST({column} AS STRING) BETWEEN '{start}' AND '{end}' THEN CAST({column} AS STRING)")
            else:
                exprs.append(f"WHEN CAST({column} AS STRING) = '{codigo}' THEN '{descripcion}'")

        if exprs:
            case_expr =  f"CASE {' '.join(exprs)} ELSE CAST({column} AS STRING) END"
        else:
            case_expr = column
        return F.expr(case_expr).alias(column)

    df_result = df_personas
    for column in df_personas.columns:
        df_result = df_result.withColumn(f"{column}_new", build_codigos_expr(df_codigos, column))
        df_result = df_result.drop(column)
        df_result = df_result.withColumnRenamed(f"{column}_new", column)

    result = df_result

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["join_4.joined_data"],
        ctx["source_5.data"]
    ],
    "data__sources": [
        {
            "node": "join_4",
            "output_port": "joined_data",
            "name": "join_personas_hogar_vivienda",
            "df_name": "join_personas_hogar_vivienda"
        },
        {
            "node": "source_5",
            "output_port": "data",
            "name": "codigos_otros_v2",
            "df_name": "codigos_otros_v2"
        }
    ]
}
out = run(config, inputs, spark)
ctx["python_6.result"] = out["result"]

# %%
"""
id: python_8
template: python
name: convert_codigos_territoriales
position:
  x: 1200
  y: 232.5
description:
  text: Replace territorial code columns with their corresponding territory names based on administrative division mappings.
  hash: a747e8ab
previewMode: "1000"
config:
  code: |-
    # inputs["data"] is a list of input DataFrames.
    # Assign your result to the variable "result".

    df_personas = inputs["data"][0]
    df_codigos_t = inputs["data"][1]

    DIVISON_COLUMNS = [
        "region", 
        "provincia", 
        "comuna",
        "hogar_region",
        "hogar_provincia",
        "hogar_comuna",
        "vivienda_region",
        "vivienda_provincia",
        "vivienda_comuna"
    ]

    def build_codigos_expr(df_codigos_t, column):
        division_map = {
            "region": "Región",
            "provincia": "Provincia",
            "comuna": "Comuna",
            "hogar_region": "Región",
            "hogar_provincia": "Provincia",
            "hogar_comuna": "Comuna",
            "vivienda_region": "Región",
            "vivienda_provincia": "Provincia",
            "vivienda_comuna": "Comuna",
        }
        division = division_map.get(column.lower())
        if not division:
            return F.col(column)
        df_codigos_t_col = df_codigos_t.filter(df_codigos_t["División Política Administrativa"] == division)
        mapping = []
        for row in df_codigos_t_col.collect():
            mapping.append(F.lit(row['Código territorial']))
            mapping.append(F.lit(row['Territorio']))
        return F.create_map(*mapping).getItem(F.col(column)).alias(column)

    df_result = df_personas
    for column in DIVISON_COLUMNS:
        df_result = df_result.withColumn(f"{column}_new", build_codigos_expr(df_codigos_t, column))
        df_result = df_result.drop(column)
        df_result = df_result.withColumnRenamed(f"{column}_new", column)

    result = df_result
input:
  - node: python_6
    input_port: data
    output_port: result
  - node: source_7
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any
from pyspark.sql import DataFrame

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    data = inputs.get("data", [] if True else None)
    result = data[0] if data else spark.createDataFrame([], "col: string")

    # inputs["data"] is a list of input DataFrames.
    # Assign your result to the variable "result".

    df_personas = inputs["data"][0]
    df_codigos_t = inputs["data"][1]

    DIVISON_COLUMNS = [
        "region", 
        "provincia", 
        "comuna",
        "hogar_region",
        "hogar_provincia",
        "hogar_comuna",
        "vivienda_region",
        "vivienda_provincia",
        "vivienda_comuna"
    ]

    def build_codigos_expr(df_codigos_t, column):
        division_map = {
            "region": "Región",
            "provincia": "Provincia",
            "comuna": "Comuna",
            "hogar_region": "Región",
            "hogar_provincia": "Provincia",
            "hogar_comuna": "Comuna",
            "vivienda_region": "Región",
            "vivienda_provincia": "Provincia",
            "vivienda_comuna": "Comuna",
        }
        division = division_map.get(column.lower())
        if not division:
            return F.col(column)
        df_codigos_t_col = df_codigos_t.filter(df_codigos_t["División Política Administrativa"] == division)
        mapping = []
        for row in df_codigos_t_col.collect():
            mapping.append(F.lit(row['Código territorial']))
            mapping.append(F.lit(row['Territorio']))
        return F.create_map(*mapping).getItem(F.col(column)).alias(column)

    df_result = df_personas
    for column in DIVISON_COLUMNS:
        df_result = df_result.withColumn(f"{column}_new", build_codigos_expr(df_codigos_t, column))
        df_result = df_result.drop(column)
        df_result = df_result.withColumnRenamed(f"{column}_new", column)

    result = df_result

    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {}
inputs = {
    "data": [
        ctx["python_6.result"],
        ctx["source_7.data"]
    ],
    "data__sources": [
        {
            "node": "python_6",
            "output_port": "result",
            "name": "convert_codigos_otros",
            "df_name": "convert_codigos_otros"
        },
        {
            "node": "source_7",
            "output_port": "data",
            "name": "codigos_territoriales",
            "df_name": "codigos_territoriales"
        }
    ]
}
out = run(config, inputs, spark)
ctx["python_8.result"] = out["result"]

# %%
"""
id: workspace.default.output_9
template: output
name: workspace.default.personas_censo2024
position:
  x: 1500
  y: 232.5
description:
  text: Save data into table 'workspace.default.personas_censo2024', replacing existing content.
  hash: 8d94afa4
previewMode: "1000"
config:
  catalog: workspace
  schema: "`default`"
  table_name: personas_censo2024
input:
  - node: python_8
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "workspace",
    "schema": "`default`",
    "table_name": "personas_censo2024"
}
inputs = {
    "data": ctx["python_8.result"]
}
out = run(config, inputs, spark)
